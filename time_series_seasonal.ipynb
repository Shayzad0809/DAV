# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayzad0809/DAV/blob/main/time_series_seasonal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'date':pd.to_datetime(['2023-01-01','2023-02-01','2023-03-01','2023-04-01','2023-05-01','2023-06-01','2023-07-01','2023-08-01','2023-09-01','2023-10-01']),
    'value':[10,21,12,13,14,55,16,97,18,169]
}
df=pd.DataFrame(data)
df.set_index('date',inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df['value'],marker='1')
plt.xlabel('date')
plt.ylabel('value')
plt.title('Time series with seasonal')
plt.grid(True)
plt.show()
