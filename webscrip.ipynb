# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayzad0809/DAV/blob/main/webscrip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
link = 'https://www.bmw.com/en/index.html'
link_text=requests.get(link).text
print(link_text)
# Out:
# <!doctype html><html lang="en"><head><meta charset="utf-8"/><link rel="preload" href="/etc.clientlibs/bmwcom/clientlibs/clientlib-site/resources/fonts/BMWTypeNextLatin.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="/etc.clientlibs/bmwcom/clientlibs/clientlib-site/resources/fonts/playfair.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1, maximum-scale=5.0"/><meta vocab="http://schema.org/" property="datePublished" content="Wed Mar 06 14:15:25 CET 2024"/><meta name="generator" content="bmwcom:2.202402.1.0"/><meta name="theme-color" content="#8e8e8e"/><link rel="manifest" href="/etc.clientlibs/settings/wcm/designs/bmwcom/base/resources/ci2020/context-bmw-com/manifest_en.json" crossorigin="use-credentials"/><link rel="icon" type="image/png" href="/etc.clientlibs/settings/wcm/designs/bmwcom/base/resources/ci2020/context-bmw-com/img/favicon.png"/><link rel
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(link_text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
print(soup.title)
print(soup.title.string)
soup.a
soup.find=all('a')
all_table=soup.find_all('table')
print(all_table)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link as="font" crossorigin="anonymous" href="/etc.clientlibs/bmwcom/clientlibs/clientlib-site/resources/fonts/BMWTypeNextLatin.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/etc.clientlibs/bmwcom/clientlibs/clientlib-site/resources/fonts/playfair.woff2" rel="preload" type="font/woff2"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, maximum-scale=5.0" name="viewport"/>
#   <meta content="Wed Mar 06 14:15:25 CET 2024" property="datePublished" vocab="http://schema.org/"/>
#   <meta content="bmwcom:2.202402.1.0" name="generator"/>
#   <meta content="#8e8e8e" name="theme-color"/>
#   <link crossorigin="use-credentials" href="/etc.clientlibs/settings/wcm/designs/bmwcom/base/resources/ci2020/context-bmw-com/manifest_en.json" rel="manifest"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os

def download_images(url, folder_path):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    img_tags = soup.find_all('img')

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    for img_tag in img_tags:
        img_url = img_tag.get('src')
        if img_url:
            img_name = os.path.basename(img_url)
            img_path = os.path.join(folder_path, img_name)
            try:
                img_data = requests.get(img_url).content
                with open(img_path, 'wb') as img_file:
                    img_file.write(img_data)
            except Exception as e:
                pass

url = 'https://www.bmw.com/en/index.html'
folder_path = 'downloaded_images'

download_images(url, folder_path)
